# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_x_r = pd.read_csv('x_r25.csv', names=['x', 'r'])
plt.scatter(df_x_r['x'], df_x_r['r'])
plt.title('Итерационная диаграмма при r = 2.5')
# Out:
# Text(0.5, 1.0, 'Итерационная диаграмма при r = 2.5')

# %%
df_x_r = pd.read_csv('x_r32.csv', names=['x', 'r'])
plt.scatter(df_x_r['x'], df_x_r['r'])
plt.title('Итерационная диаграмма при r = 3.2')
# Out:
# Text(0.5, 1.0, 'Итерационная диаграмма при r = 3.2')

# %%
df_x_r = pd.read_csv('x_r35.csv', names=['x', 'r'])
plt.scatter(df_x_r['x'], df_x_r['r'])
plt.title('Итерационная диаграмма при r = 3.5')
# Out:
# Text(0.5, 1.0, 'Итерационная диаграмма при r = 3.5')

# %%
df_x_r = pd.read_csv('x_r38.csv', names=['x', 'r'])
plt.scatter(df_x_r['x'], df_x_r['r'])
plt.title('Итерационная диаграмма при r = 3.8')
# Out:
# Text(0.5, 1.0, 'Итерационная диаграмма при r = 3.8')

# %%
df_x_r = pd.read_csv('mod_r.csv', names=['r', 'num_mods'])
plt.plot(df_x_r['r'], df_x_r['num_mods'])
plt.title('График количества mod от r')
# Out:
# Text(0.5, 1.0, 'График количества mod от r')
